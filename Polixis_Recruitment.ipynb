# %%
from IPython.core.interactiveshell import InputRejected
from time import sleep
sleep (0.75)
print (""" ___   ___   _     _   _     _   __""")
sleep (0.75)
print ("""| |_) / / \ | |   | | \ \_/ | | ( (`""")
sleep (0.75)
print ("""|_|   \_\_/ |_|__ |_| /_/ \ |_| _)_)""")
sleep (1)
print ("")
print ("Welcome to Polixis Sàrl.") 
sleep(2)
print ("My name's Garen, your virtual recruiter.")
sleep(2)
answer = str(input ("""What's your name."""))
print ("_____________________________________________________")

if len(answer) == 0:
  print ("Just type something you moron (Reset the program).")

if any(char.isdigit() for char in answer):
    print ("What, are you a robot? \nPlease type your REAL name by resetting the program.")

if answer.isnumeric():
    print ("At least type a letter you idiot!")
if len(answer) < 4 and len(answer) > 0 and answer.isalpha():
    print ("Your name seems pretty short, you can type in your full name by \nresetting the program.")
if answer == "garen" or answer == "Garen":
    print ("Greetings master...")
if len(answer) > 20 and answer.isalpha():
    print ("WOW, that's a long-ass name! Type your REAL name by \nresetting the program.")
if answer.isalpha() and len(answer)> 4 and len(answer) < 20 or len(answer) == 4:
    sleep(1.5)
    print ("")
    print ("Hmm...")
    sleep(1.5)
    print ("")
    print (f"Well {answer.capitalize()} jan..." ) 
    sleep(2)
    print ("")
    print ("Which department do you want to apply for?") 
    sleep(1)
    print ("")
    print ("A-Data")
    sleep(1)
    print ("B-IT")
    sleep(1)
    answerjob = str(input ("Type your option."))
    print ("_____________________________________________________")
#Data Researcher Path
    if answerjob == "A" or answerjob == "a":
      sleep(1)
      print ("")
      print ("Alright, I see. Do you have a Bachelor's degree?")
      sleep(0.9)
      answerbachelor = str(input ("""Type "Y" if you have, and "N" if you don't."""))
      if answerbachelor == "Y" or answerbachelor == "y":
        sleep(1)      
        print (f"That's good {answer.capitalize()}") 
        print ("Would you be able to send us your CV, also your cover letter?")
        answercoverl = str(input ("Type 'Y' for yes, and 'N' for no."))
        if answercoverl == "Y" or answercoverl == "y":
          print ("Great! Would you send them to this email address: \nmyjob@polixis.com")
        if answercoverl == "N" or answercoverl == "n":
          print ("Sorry! Your application will not be considered without your CV and your cover letter.")
      elif answerbachelor == "N" or answerbachelor == "n":
        print ("Are you currently a student?")
        answerstu = str(input ("""Type either "Y" or "N." """))
        if answerstu == "Y" or answerstu == "y":
          print ("Would you be able to work full-time?")
          answerft = str(input ("""Type either "Y" or "N." """))
          if answerft == "Y" or answerft == "y":
            print ("Perfect! Please send your CV to this e-mail address:\nmyjob@polixis.com")
          elif answerft == "N" or answerft == "n":
            print ("Sorry! We require full-time employees.")
        elif answerstu == "N" or answerstu == "n":
          print (f"Dear {answer.capitalize()}, how are you supposed to find a job without a degree?")
      else:
        print ("huh?")
#IT Path
    if answerjob == "B" or answerjob == "b":
      print("")
      sleep(1)
      print ("IT?")
      sleep(1)
      print (f"Alright {answer.capitalize()}, how many years of experience do you have in software development?")
      sleep(1)
      answerxp = str(input ("""Type your answer:"""))
      if answerxp < "3":
        print ("Sorry, you do not have enough experience.")
      elif answerxp == "3" or answerxp > "3" or answerxp == "10" or answerxp > "10":
        print ("Which programming language do you know best?")
        sleep(1)
        print ("1-Java")
        sleep(0.25)
        print ("2-JavaScript")
        sleep(0.25)
        print ("3-C")
        sleep(0.25)
        print ("4-C+")
        sleep(0.25)
        print ("5-C++")
        sleep(0.25)
        print ("6-C#")
        sleep(0.25)
        print ("7-Python")
        sleep(0.25)
        print ("8-PHP")
        sleep(0.25)
        print ("9-Other")
        answerlang = str(input ("""Please select the one you're most experienced in:"""))
        if answerlang == "1":
          print ("That's perfect. In fact we are hiring Java engineers constantly.\nPlease submit your CV to this email address: myjob@polixis.com")
        elif answerlang == "2":
          print ("Great, we needed a Front-End developer.\nPlease submit your CV to this email address: myjob@polixis.com")
        elif answerlang == "3":
          print ("Sorry, we do not need C developers right now.\nHowever, there might be an opening in the future.")
          print ("You are more than welcome to submit your CV to this email address:")
          print ("myjob@polixis.com")
        elif answerlang == "4":
          print ("Sorry, we do not need C+ developers right now.\nHowever, there might be an opening in the future.")
          print ("You are more than welcome to submit your CV to this email address:")
          print ("myjob@polixis.com")
        elif answerlang == "5":
          print ("Sorry, we do not need C++ developers right now.\nHowever, there might be an opening in the future.")
          print ("You are more than welcome to submit your CV to this email address:")
          print ("myjob@polixis.com")
        elif answerlang == "6":
          print ("Sorry, we do not need C# developers right now.\nHowever, there might be an opening in the future.")
          print ("You are more than welcome to submit your CV to this email address:")
          print ("myjob@polixis.com")
        elif answerlang == "7":
          print ("Are an ML engineer?")
          sleep(0.5)
          answerml = str(input ("""Type either "Yes" or "No":"""))
          #To ML or not to ML, that is the question...
          if answerml == "Yes" or answerml == "yes" or answerml == "Yes." or answerml == "yes." or answerml == "YES" or answerml == "YES.":
            print ("Perfect, then please send your CV to this email address:")
            print ("myjob@polixis.com")
          elif answerml == "No" or answerml == "no" or answerml == "No." or answerml == "no." or answerml == "NO" or answerml =="NO.":
            print ("Sorry, we are only looking for ML Engineers with Python knowledge.")
          else:
            print ("How hard is it to type a single word?")
        elif answerlang == "8":
          print ("Sorry, we do not need PHP developers right now.\nHowever, there might be an opening in the future.")
          print ("You are more than welcome to submit your CV to this email address:")
          print ("myjob@polixis.com")
        elif answerlang == "9":
          print ("Hmm...")    
      else:
        print ("Please enter a valid number.")
# Out:
#  ___   ___   _     _   _     _   __
# | |_) / / \ | |   | | \ \_/ | | ( (`
# |_|   \_\_/ |_|__ |_| /_/ \ |_| _)_)
#
# Welcome to Polixis Sàrl.
# My name's Garen, your virtual recruiter.
# What's your name.garen
# _____________________________________________________
# Greetings master...
#
# Hmm...
#
# Well Garen jan...
#
# Which department do you want to apply for?
#
# A-Data
# B-IT
# Type your option.a
# _____________________________________________________
#
# Alright, I see. Do you have a Bachelor's degree?
# Type "Y" if you have, and "N" if you don't.n
# Are you currently a student?
# Type either "Y" or "N." n
# Dear Garen, how are youı supposed to find a job without a degree?
